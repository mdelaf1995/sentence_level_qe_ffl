# %% [markdown]
# # To do:
#     - Lemmatization of the german words to compute the sentiments analysis
#     - Multilingual word embedding // compare the mean of the vectors for each of the different POS tagging (reduced) per sentence // could do it on full sentence as well (high potential ie 0.0052 correlation)
#     - Difference in the numbers of POS tagging per sentence
#     - Work on named entities to separate the proper nouns from film titles etc...
#     - Read papers
#     - Test first models
#
#     - Look at examples and store the ones where we do not understand the poor score **throughout**

# %% [markdown]
# compare the POS in both english and german. Are there any difference? Would the above analysis hold?

# %% [markdown]
# read papers
